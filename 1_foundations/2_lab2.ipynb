# %% [markdown]
# ## Welcome to the Second Lab - Week 1, Day 3
#
# Today we will work with lots of models! This is a way to get comfortable with APIs.

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Important point - please read</h2>
#             <span style="color:#ff7800;">The way I collaborate with you may be different to other courses you've taken. I prefer not to type code while you watch. Rather, I execute Jupyter Labs, like this, and give you an intuition for what's going on. My suggestion is that you carefully execute this yourself, <b>after</b> watching the lecture. Add print statements to understand what's going on, and then come up with your own variations.<br/><br/>If you have time, I'd love it if you submit a PR for changes in the community_contributions folder - instructions in the resources. Also, if you have a Github account, use this to showcase your variations. Not only is this essential practice, but it demonstrates your skills to others, including perhaps future clients or employers...
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# Start with imports - ask ChatGPT to explain any package that you don't know

import os
import json
from dotenv import load_dotenv
from openai import OpenAI
from anthropic import Anthropic
from IPython.display import Markdown, display

# %%
# Always remember to do this!
load_dotenv(override=True)
# Out:
# True

# %%
# Print the key prefixes to help with any debugging

openai_api_key = os.getenv('OPENAI_API_KEY')
anthropic_api_key = os.getenv('ANTHROPIC_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
deepseek_api_key = os.getenv('DEEPSEEK_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
    
if anthropic_api_key:
    print(f"Anthropic API Key exists and begins {anthropic_api_key[:7]}")
else:
    print("Anthropic API Key not set (and this is optional)")

if google_api_key:
    print(f"Google API Key exists and begins {google_api_key[:2]}")
else:
    print("Google API Key not set (and this is optional)")

if deepseek_api_key:
    print(f"DeepSeek API Key exists and begins {deepseek_api_key[:3]}")
else:
    print("DeepSeek API Key not set (and this is optional)")

if groq_api_key:
    print(f"Groq API Key exists and begins {groq_api_key[:4]}")
else:
    print("Groq API Key not set (and this is optional)")
# Out:
# OpenAI API Key exists and begins sk-proj-
# Anthropic API Key not set (and this is optional)
# Google API Key not set (and this is optional)
# DeepSeek API Key not set (and this is optional)
# Groq API Key not set (and this is optional)

# %%
request = "Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. "
request += "Answer only with the question, no explanation."
messages = [{"role": "user", "content": request}]

# %%
messages
# Out:
# [{'role': 'user',
#   'content': 'Please come up with a challenging, nuanced question that I can ask a number of LLMs to evaluate their intelligence. Answer only with the question, no explanation.'}]

# %%
openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=messages,
)
question = response.choices[0].message.content
print(question)
# Out:
# Imagine you are an advisor to a mid-sized coastal city that expects a 30% population increase over the next 15 years, faces projected sea-level rise that will make significant portions of low-lying neighborhoods uninhabitable within 40 years, and has a municipal budget that can only grow about 1% per year in real terms: using explicit assumptions, propose a prioritized 15-year policy and investment plan that (a) protects the most vulnerable residents, (b) preserves economic vitality, and (c) minimizes long-term costs and displacement; for each major action, provide the rationale, order-of-magnitude cost and benefit estimates (or explain why such estimates are infeasible), key performance indicators, likely unintended consequences and mitigation strategies, and a clear monitoring and adaptation protocol if outcomes deviate from expectations; state what additional data you would collect to reduce uncertainty, how you would detect and correct for biases in that data, and how you would design equitable community engagement in decision-making; finally, identify three critical moral dilemmas policymakers will face in implementing your plan and explain how you would weigh competing values in those dilemmas.

# %%
competitors = []
answers = []
messages = [{"role": "user", "content": question}]

# %% [markdown]
# ## Note - update since the videos
#
# I've updated the model names to use the latest models below, like GPT 5 and Claude Sonnet 4.5. It's worth noting that these models can be quite slow - like 1-2 minutes - but they do a great job! Feel free to switch them for faster models if you'd prefer, like the ones I use in the video.

# %%
# The API we know well
# I've updated this with the latest model, but it can take some time because it likes to think!
# Replace the model with gpt-4.1-mini if you'd prefer not to wait 1-2 mins

model_name = "gpt-5-nano"

response = openai.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# Below is a structured, explicit plan for a mid-sized coastal city facing rapid population growth, rising sea level, and a tight budget. The plan prioritizes protecting the most vulnerable, preserving economic vitality, and minimizing long-term costs and displacement. All costs are provided as order-of-magnitude estimates and are clearly labeled when precise figures are infeasible.
#
# 1) Explicit assumptions guiding the plan
# - Population: current ~500,000 residents; projected +30% over 15 years (≈650,000 by year 15).
# - Climate hazard: by year 40, significant portions of low-lying neighborhoods risk uninhabitability due to sea-level rise and extreme coastal flooding; 15–25% of land area (and corresponding housing stock) are at high exposure under moderate to high sea-level scenarios.
# - Budget reality: municipal operating budget today ~$1.2B/year with real-growth capacity ~1%/year; capital and resilience investments must be financed within or beyond this envelope, leveraging state/federal grants, bonds, and public-private partnerships.
# - Time horizon: 15-year prioritized plan with annual milestones and mid-course adaptation points, plus a longer-term, post-plan trajectory focused on resilience and equity.
# - Equity lens: explicit attention to renters, low-income households, seniors, people with disabilities, and languages other than English; engagement and implementation designed to avoid widening inequities.
#
# 2) Prioritized 15-year plan (five major actions)
#
# Action 1. Protect the most vulnerable residents and critical services with resilience infrastructure (hybrid approach: nature-based and engineered solutions)
# - Rationale and goal: Reduce exposure of the most at-risk households and essential public services (hospitals, schools, shelters, water/sewer treatment, emergency operations centers) to flood and sea-level rise, buying time for adaptation and minimizing displacement.
# - Scope (highlights):
#   - Targeted flood defense upgrades around the most exposed neighborhoods and essential facilities.
#   - Nature-based protections (living shorelines, wetlands restoration, dune management) where feasible to reduce flood energy and provide co-benefits (habitat, recreation, carbon sequestration).
#   - Drainage system upgrades, backflow protections, lifting stations, and climate-resilient infrastructure for critical facilities.
#   - Incorporate climate-resilient design into all new capital projects (elevations, flood-proofing, waterproofing, backup power, and redundancy).
# - Order-of-magnitude cost: roughly $2–6 billion over 15 years (phased, with the heaviest work concentrated in the near- to mid-term; exact costs depend on site-specific designs and contingency needs).
# - Expected benefits (order of magnitude): substantial reduction in expected annual flood damages for protected zones (target 30–60% reduction in modeled losses within protected areas); reduced disruption to essential services; lower insurance exposure; improved safe-haven capacity during storms.
# - Key performance indicators (KPIs):
#   - Percentage of high-risk population and critical facilities protected to defined flood depth/return-period thresholds.
#   - Number of critical facilities with upgraded flood defenses and redundant power.
#   - Reduction in expected annual flood damages (dollarized risk reduction).
#   - Time-to-completion and adherence to budget for prioritized segments.
# - Unintended consequences and mitigations:
#   - Barrier-induced growth pressures and potential displacement nearby (amplified property values and gentrification). Mitigation: pair with anti-displacement measures, inclusive zoning, and affordable housing requirements.
#   - Ecological trade-offs from hard infrastructure. Mitigation: complementary nature-based features, careful site selection, and ongoing ecological monitoring.
# - Monitoring/adaptation protocol:
#   - Establish a resilience monitor panel with quarterly reviews; implement a dashboard tracking exposure, project milestones, costs, and service interruptions.
#   - Trigger-based adaptivity: if actual flood events exceed projections or protection performance underperform, accelerate additional protections or re-scope to higher-return options.
# - Data needs and bias considerations:
#   - Data to collect: hazard maps, high-resolution flood depths, critical facility inventories, population in flood-prone zones, property valuations, insurance status, and social vulnerability indicators.
#   - Bias mitigation: triangulate multiple data sources (municipal records, state GIS, utility data, community surveys); ensure sampling includes renters and marginalized communities; implement data validation with independent audits.
# - Equitable community engagement design:
#   - Early and ongoing community advisory groups with representation from renters, seniors, people with disabilities, non-English speakers, and low-income residents.
#   - Multilingual public meetings at accessible times and venues; provide childcare and transportation stipends; transparent project maps, costs, and trade-offs; community demonstrations and pilot sites.
#   - Use participatory design workshops to gather local knowledge on risk perception and preferred protection strategies.
#
# Action 2. Implement a voluntary managed retreat and relocation program for the most at-risk residents and facilities
# - Rationale and goal: Proactively reduce exposure by relocating households and non-resilient facilities from the most hazard-prone zones, while ensuring dignity, choice, and equitable access to safe housing and services.
# - Scope (highlights):
#   - Voluntary buyout/subsidized relocation options for households in the deepest risk zones.
#   - Replacement housing in safer areas, prioritized near jobs and transit to minimize economic disruption.
#   - Land-use planning tools to avoid reconstructing in high-risk zones (buyout-ready parcels; strategic land swaps).
#   - Behavioral and relocation support: counseling, moving assistance, and employment transition services.
# - Order-of-magnitude cost: roughly $0.5–2.5 billion, depending on the number of households opted into relocation and the price of replacement housing; includes subsidies, incentives, and program administration.
# - Expected benefits: reduced long-term hazard exposure; avoided future expensive exhumations or disaster-driven relocation; preserved overall city economic vitality by enabling safer density near employment centers.
# - KPIs:
#   - Share of high-risk households offered and accepting voluntary relocation options.
#   - Replacement housing availability and occupancy rates.
#   - Net displacement avoided (households stabilized in safer areas).
#   - Time-to-relocation and administrative costs per household.
# - Unintended consequences and mitigations:
#   - Perceived loss of community, neighborhood identity, and property values. Mitigation: ensure meaningful resident choice, invest in community relocation neighborhoods that foster social ties, and provide neighborhood revitalization funds for remaining or receiving areas.
#   - Potential adverse impacts on sending-area property markets. Mitigation: targeted outreach, tax-credit protections for remaining residents, and demolition/land-use planning that stabilizes property values.
# - Monitoring/adaptation protocol:
#   - Annual cohort tracking of participants; dashboards on relocation outcomes; adjust eligibility and incentives to meet demand while preserving fiscal discipline.
#   - Contingency plan if uptake is lower/higher than expected: scale incentives or expand to adjacent safe zones; reassess timing with hazard projections.
# - Data needs and bias considerations:
#   - Data: household risk profiles, housing costs, family size, income, mobility availability, and proximity to jobs.
#   - Bias mitigation: ensure outreach captures renters and unaffordable housing situations; independent evaluations to verify who takes buyouts versus who stays; avoid skipping marginalized groups.
# - Equitable community engagement design:
#   - Early transparent information about risks and options; neutral third-party facilitators; accessible, culturally competent outreach; inclusive decision-making processes with guaranteed representation for vulnerable groups; time-limited pilot buyouts followed by expansion based on demonstrated need and capacity.
#
# Action 3. Housing strategy and inclusive urban development to preserve affordability and minimize displacement
# - Rationale and goal: Ensure that as the city grows and climate hazards rise, households have access to affordable, resilient housing near jobs and services, preventing relocation pressure on lower-income residents.
# - Scope:
#   - Inclusionary zoning and density bonuses near transit; preserve and retrofit existing affordable housing stock with flood-proofing.
#   - Financing tools: resilience-linked subsidies, housing trust funds, and targeted rental assistance.
#   - Replacement housing and renter protections during floods/disruptions.
# - Order-of-magnitude cost: $0.5–2.0 billion in capital and subsidies over 15 years (plus ongoing operating expenditures for subsidies), depending on the extent of affordable housing preservation/creation.
# - Expected benefits: lower displacement risk, stabilized neighborhood demographics, preserved labor force in service sectors and construction, enhanced tax base resilience.
# - KPIs:
#   - Percentage of new housing units that are affordable and located in resilient zones.
#   - Occupancy stability among low-income residents and renters.
#   - Rent and vacancy trends in at-risk districts.
#   - Time-to-permit for resilient housing projects.
# - Unintended consequences and mitigations:
#   - Potential pushback from existing homeowners on higher density. Mitigation: clear benefits to community, inclusionary requirements with buy-in from residents, and strong local infrastructure capacity improvements.
#   - Gentrification pressures in safe zones. Mitigation: targeted anti-displacement policies, tenant protections, and affordable housing set-asides.
# - Monitoring/adaptation protocol:
#   - Annual housing market and affordability dashboard; monitor displacement risk indices; adjust zoning and incentives as needed.
# - Data needs and bias considerations:
#   - Data: rent levels, vacancy rates, income distributions, housing stock ages, flood exposure by building, transit access.
#   - Bias mitigation: ensure renter data is included, avoid undercounting informal housing; cross-check with housing authority and HUD data; partner with community organizations for accurate local context.
# - Equitable community engagement design:
#   - Stakeholder workshops with tenants’ associations, faith-based groups, and immigrant/refugee communities; multilingual public information; decision-making processes that empower renters and low-income residents; micro-grants for community-led redevelopment ideas.
#
# Action 4. Climate-resilient economic vitality: protect and adapt key economic assets (ports, tourism, downtowns, essential businesses)
# - Rationale and goal: Preserve the city’s economic base and resilience by safeguarding critical economic hubs and supply chains, while attracting climate-resilient investment.
# - Scope:
#   - Upgrade port and logistics facilities to withstand higher water levels and more frequent storms; protect downtown and commercial corridors with resilient drainage, elevated first floors, and floodproofing of essential utilities.
#   - Supporting small and medium-sized enterprises (SMEs) with resilience grants, technical assistance, and disaster-preparedness training.
#   - Diversify economic base (e.g., green jobs, climate-adaptation tech, coastal recreation economy) to reduce reliance on a single sector.
# - Order-of-magnitude cost: approximately $1–3B, depending on port upgrades, downtown protections, and SME support scale.
# - Expected benefits: continuity of business, reduced flood-related closures, protected tax base, job stability, and new climate-related employment opportunities.
# - KPIs:
#   - Time-to-reopen after storms; reduction in days of business closures due to flooding.
#   - Number of SMEs participating in resilience programs; survival rates after storms.
#   - Revenue resilience metrics for key sectors; diversification indices.
#   - Flood-damage reduction for critical economic zones (target % reduction in expected losses).
# - Unintended consequences and mitigations:
#   - Potential increases in land values and rents near protected zones. Mitigation: ensure affordable commercial space for small businesses; apply equitable leasing practices; cap rent increases during post-disaster recovery.
#   - Prioritization biases toward wealthier districts. Mitigation: equity-based allocation criteria; explicit targeting of historically underserved commercial corridors.
# - Monitoring/adaptation protocol:
#   - Economic resilience dashboard with quarterly reporting on business continuity metrics, investment leveraged, and employment impacts.
#   - If storms become more severe than modeled, accelerate protections in the most exposed corridors and deploy additional SME support.
# - Data needs and bias considerations:
#   - Data: business registry, employment by sector, supply-chain dependencies, flood-risk exposure of commercial parcels, tourism demand, and customer footfall data.
#   - Bias mitigation: supplement official registries with small business surveys, ensure inclusion of informal enterprises, and correct undercounts in marginalized districts.
# - Equitable community engagement design:
#   - Outreach to business associations representing historically underserved communities; inclusive input on which corridors most need protection; multilingual business assistance programs; ensure small businesses receive adequate notice and support to access funding.
#
# Action 5. Data, governance, financing, and community engagement backbone (monitoring, learning, and adaptive management)
# - Rationale and goal: Create a transparent, accountable, data-driven governance framework that continuously learns, adapts, and equitably distributes resources across the city’s vulnerable and non-vulnerable populations.
# - Scope:
#   - Establish a city resilience data platform with standardized indicators, open data where appropriate, and privacy protections for individuals.
#   - Transparent budgeting for resilience investments; establish a resilience revolving fund; pursue federal/state grants and climate bonds; implement performance-based contracting for resilience projects.
#   - Formalized community engagement processes: regular public dashboards, participatory budgeting elements, and citizen assemblies with compensation for participation.
# - Order-of-magnitude cost: $100–400 million in setup and ongoing management over 15 years (primarily in governance staff, IT systems, and program delivery; annual operating costs modest relative to capital investments).
# - Expected benefits: better prioritization, increased public trust, more equitable investment distribution, and faster course corrections when risks or outcomes diverge from projections.
# - KPIs:
#   - Data platform uptime, data quality scores, and adoption rates by departments.
#   - Share of resilience funds allocated via transparent, criteria-based processes.
#   - Public participation metrics (participation rates across neighborhoods, linguistic groups, renters vs. owners).
#   - Time to implement corrective actions when performance misses targets.
# - Unintended consequences and mitigations:
#   - Data privacy concerns; mitigate with robust privacy protocols and minimization of sensitive data collection.
#   - Potential participatory fatigue; mitigate with rotating seats, token compensation, and clear decision-making authority.
# - Monitoring/adaptation protocol:
#   - Quarterly governance reviews; annual independent red-teaming of plans and budgets; mid-course reallocation if outcomes diverge from targets.
# - Data needs and bias considerations:
#   - Data: baseline vulnerability indices, income/age demographics, housing tenure, health indicators, infrastructure performance, historical disaster data, and climate projections.
#   - Bias mitigation: ensure sampling represents all neighborhoods; use multiple data sources; conduct bias audits; engage independent evaluators.
# - Equitable community engagement design:
#   - Structured, ongoing engagement with explicit commitments to shared decision-making; multilingual communication; accessible formats; compensation for time; capacity-building components to enable meaningful participation from marginalized residents.
#
# 3) Financing, implementation, and risk management
# - Financing mix (illustrative):
#   - Municipal bonds and dedicated resilience revenue streams (short/medium-term debt) in the range of $1–3B.
#   - Federal/state grants and mitigation funds (matching grants, FEMA/BRIC-type programs).
#   - Public-private partnerships for specific projects (e.g., waterfront developments with resilience features).
#   - Local but targeted revenue sources with protections for low-income households (e.g., resilience-linked subsidies rather than broad-based regressive taxes).
# - Fiscal discipline: align capital investments with the 15-year budget forecast (operating budget grows ~1% real per year; resilience debt service backed by a mix of tax revenues, grants, and user fees where appropriate); maintain a reserve to absorb climate and economic shocks.
# - Phasing and sequencing: begin with high-priority, high-impact investments in Action 1 (protecting vulnerable residents and critical services) and Action 5 (data/governance backbone) in year 1–2; progress to managed retreat planning (Action 2) and housing/economic measures (Actions 3 and 4) in years 2–8; evaluate and recalibrate every 3–4 years with a formal mid-course review.
#
# 4) Data, bias detection, and equitable engagement plan
# - Data to collect to reduce uncertainty:
#   - Hazard exposure (flood depth, surge, wind, rainfall) at high spatial resolution; sea-level rise scenarios; climate projections.
#   - Building stock, age, construction type, flood vulnerability, insurance status, and current and projected occupancy.
#   - Population demographics by neighborhood (income, race/ethnicity, language, age, disability status, housing tenure).
#   - Economic data: major employers, supply chains, tourism demand, and business vitality indicators; transit and housing proximity to employment.
#   - Infrastructure status: utility redundancy, backup power, water/sewer capacity, transportation reliability during storms.
# - Detecting and correcting biases:
#   - Use triangulation: compare municipal records with third-party datasets (state/federal agencies, academic climate models, utility data, census updates).
#   - Regular bias audits and sensitivity analyses: test how different data sources shift priorities; adjust weighting to correct known gaps (e.g., renters, undocumented or informal housing).
#   - Community validation: hold participatory data validation sessions with neighborhood groups; incorporate community-provided data (e.g., flood experiences, informal housing arrangements).
# - Equitable community engagement design:
#   - Early, ongoing, multi-channel engagement with explicit commitments to represent marginalized groups.
#   - Multilingual outreach, accessible venues, childcare and transportation stipends, and compensation for participant time.
#   - Participatory budgeting elements and community representation in planning bodies; transparent materials including trade-offs and cost implications.
#   - Independent ombudsperson and grievance mechanism for communities to flag concerns about equity or process.
#
# 5) Three critical moral dilemmas policymakers will face and how to weigh values
# Dilemma 1: Protecting property and neighborhoods vs. managed retreat for safety
# - Dilemma: Should the city aggressively protect existing neighborhoods (including wealthier areas) or prioritize voluntary relocation and protection for the most vulnerable, even if this means abandoning some areas?
# - Value tensions: safety and life preservation; equity and dignity; property rights; cost efficiency.
# - Approach: prioritize voluntary, well-compensated relocations with replacement housing in safer zones; preserve life and health outcomes as the primary metric; use targeted protections in high-risk areas while still encouraging redevelopment and safe use of land elsewhere. Ensure transparent criteria, strong renter protections, and community-led relocation planning to respect attachment to place and social networks.
#
# Dilemma 2: Financing resilience vs. burden on current residents vs. future residents
# - Dilemma: How to distribute costs between current residents (who may bear higher taxes or debt) and future residents (who may benefit from long-term resilience), while avoiding regressive impacts on low-income households?
# - Value tensions: intergenerational equity; fairness; economic development; political feasibility.
# - Approach: mix of progressive financing (e.g., resilience bonds, grants, and subsidies targeted to low-income communities; subsidies for renters and small businesses), paired with targeted grants and incentives for developers that provide affordable housing and resilient infrastructure. Build in sunset provisions and performance-based debt service; protect vulnerable households with caps on tax/NZ costs and direct subsidies.
#
# Dilemma 3: Hard infrastructure vs. nature-based and community-led solutions
# - Dilemma: Should the city rely mainly on engineered defenses (seawalls, pumped drainage) or emphasize nature-based solutions and community-driven planning that may take longer to implement but offer broader co-benefits?
# - Value tensions: immediacy of protection vs. ecological co-benefits; cost certainty vs. long-run resilience and equity; local authority vs state/federal standards.
# - Approach: adopt a hybrid strategy combining both approaches. Prioritize nature-based and community-informed solutions where feasible to maximize co-benefits and resilience, while deploying engineered protections in locations where immediate, high-protection needs exist. Ensure community participation in siting and design to align with local values and equity.
#
# Monitoring, adaptation, and data governance protocol
# - Establish a 15-year resilience dashboard with quarterly progress reviews and an annual independent audit.
# - Define triggers for mid-course adjustments: if hazard projections are revised upward; if actual costs exceed budgets by a defined margin; if equity metrics show worsening outcomes for vulnerable groups.
# - Maintain transparent reporting: publish project statuses, budget variances, and outcomes; release open data on risk exposure and resilience investments with privacy protections.
# - Regularly update climate scenarios and incorporate new science; adjust phasing and prioritization accordingly.
#
# What additional data would reduce uncertainty, and how to handle biases
# - Collect: high-resolution hazard data, post-disaster performance data, housing-tenure and affordability data by neighborhood, labor market resilience metrics, and housing stock vulnerability.
# - Detect bias: compare multiple sources, conduct bias audits, and include community-provided data; ensure representation in data that covers renters, non-English-speaking households, seniors, and people with disabilities.
# - Correct biases: weight data from underrepresented groups more heavily; run sensitivity analyses to see how results change with different data assumptions; adjust outreach and engagement to fill data gaps.
#
# Equity-focused community engagement
# - Create a standing, diverse community advisory council with rotating seats for renters, people with disabilities, seniors, and immigrant communities; implement participatory budgeting components for small resilience investments.
# - Ensure materials are multilingual; hold meetings at accessible locations and times; provide transportation stipends and childcare; compensate participants for time; use multiple channels (in-person, digital, radio, community centers) to reach diverse residents.
# - Establish a community-mediated feedback loop: community concerns documented, tracked, and acted upon; provide clear timelines for responses and actions.
#
# Expected challenges and how to respond
# - Political feasibility: resilience investments are costly and long term; build strong public communication about risk, co-benefits, and equity to maintain public support.
# - Managing displacement risk: ensure proactive protections for renters and vulnerable groups; provide housing subsidies and rights protections to prevent further marginalization.
# - Data privacy: ensure robust privacy safeguards in data sharing and open-data initiatives; limit access to sensitive information and anonymize datasets.
#
# In sum
# - The plan centers on protecting vulnerable residents and essential services first, with targeted managed retreat where necessary, while preserving economic vitality through resilient housing, diversified economy, and protected infrastructure.
# - Costs are substantial but feasible within a 15-year horizon when financed with a mix of bonds, grants, and targeted subsidies, and when funding is prioritized and sequenced carefully.
# - Data-driven governance, transparent engagement, and equity restoration mechanisms are built in to reduce uncertainty, detect bias, and ensure fair, community-endorsed outcomes.
# - The three moral dilemmas highlighted—protecting property vs. retreat, fair financing, and hard vs. nature-based solutions—are addressed by prioritizing safety and equity, using a blended strategy, and maintaining transparent decision processes with strong resident involvement.
#
# If you’d like, I can tailor these estimates to a concrete city profile (actual population, budget figures, land area, hazard maps) and build a more detailed, line-item phased budget with financing assumptions and a 15-year Gantt-style timeline.

# %%
# Anthropic has a slightly different API, and Max Tokens is required
# Can't be used without API Key , review with paid model

model_name = "claude-sonnet-4-5"

claude = Anthropic()
response = claude.messages.create(model=model_name, messages=messages, max_tokens=1000)
answer = response.content[0].text

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
#Gemini is also an option to buy

gemini = OpenAI(api_key=google_api_key, base_url="https://generativelanguage.googleapis.com/v1beta/openai/")
model_name = "gemini-2.5-flash"

response = gemini.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
deepseek = OpenAI(api_key=deepseek_api_key, base_url="https://api.deepseek.com/v1")
model_name = "deepseek-chat"

response = deepseek.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %%
# Updated with the latest Open Source model from OpenAI

groq = OpenAI(api_key=groq_api_key, base_url="https://api.groq.com/openai/v1")
model_name = "openai/gpt-oss-120b"

response = groq.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)

# %% [markdown]
# ## For the next cell, we will use Ollama
#
# Ollama runs a local web service that gives an OpenAI compatible endpoint,
# and runs models locally using high performance C++ code.
#
# If you don't have Ollama, install it here by visiting https://ollama.com then pressing Download and following the instructions.
#
# After it's installed, you should be able to visit here: http://localhost:11434 and see the message "Ollama is running"
#
# You might need to restart Cursor (and maybe reboot). Then open a Terminal (control+\`) and run `ollama serve`
#
# Useful Ollama commands (run these in the terminal, or with an exclamation mark in this notebook):
#
# `ollama pull <model_name>` downloads a model locally
# `ollama ls` lists all the models you've downloaded
# `ollama rm <model_name>` deletes the specified model from your downloads

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/stop.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Super important - ignore me at your peril!</h2>
#             <span style="color:#ff7800;">The model called <b>llama3.3</b> is FAR too large for home computers - it's not intended for personal computing and will consume all your resources! Stick with the nicely sized <b>llama3.2</b> or <b>llama3.2:1b</b> and if you want larger, try llama3.1 or smaller variants of Qwen, Gemma, Phi or DeepSeek. See the <A href="https://ollama.com/models">the Ollama models page</a> for a full list of models and sizes.
#             </span>
#         </td>
#     </tr>
# </table>

# %%
# !ollama pull llama3.2

# %%
ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
model_name = "llama3.2"

response = ollama.chat.completions.create(model=model_name, messages=messages)
answer = response.choices[0].message.content

display(Markdown(answer))
competitors.append(model_name)
answers.append(answer)
# Out:
# ---------------------------------------------------------------------------
# ConnectError                              Traceback (most recent call last)
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpx\_transports\default.py:101, in map_httpcore_exceptions()
#     100 try:
# --> 101     yield
#     102 except Exception as exc:
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpx\_transports\default.py:250, in HTTPTransport.handle_request(self, request)
#     249 with map_httpcore_exceptions():
# --> 250     resp = self._pool.handle_request(req)
#     252 assert isinstance(resp.stream, typing.Iterable)
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:256, in ConnectionPool.handle_request(self, request)
#     255     self._close_connections(closing)
# --> 256     raise exc from None
#     258 # Return the response. Note that in this case we still have to manage
#     259 # the point at which the response is closed.
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpcore\_sync\connection_pool.py:236, in ConnectionPool.handle_request(self, request)
#     234 try:
#     235     # Send the request on the assigned connection.
# --> 236     response = connection.handle_request(
#     237         pool_request.request
#     238     )
#     239 except ConnectionNotAvailable:
#     240     # In some cases a connection may initially be available to
#     241     # handle a request, but then become unavailable.
#     242     #
#     243     # In this case we clear the connection and try again.
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpcore\_sync\connection.py:101, in HTTPConnection.handle_request(self, request)
#     100     self._connect_failed = True
# --> 101     raise exc
#     103 return self._connection.handle_request(request)
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpcore\_sync\connection.py:78, in HTTPConnection.handle_request(self, request)
#      77 if self._connection is None:
# ---> 78     stream = self._connect(request)
#      80     ssl_object = stream.get_extra_info("ssl_object")
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpcore\_sync\connection.py:124, in HTTPConnection._connect(self, request)
#     123 with Trace("connect_tcp", logger, request, kwargs) as trace:
# --> 124     stream = self._network_backend.connect_tcp(**kwargs)
#     125     trace.return_value = stream
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpcore\_backends\sync.py:207, in SyncBackend.connect_tcp(self, host, port, timeout, local_address, socket_options)
#     202 exc_map: ExceptionMapping = {
#     203     socket.timeout: ConnectTimeout,
#     204     OSError: ConnectError,
#     205 }
# --> 207 with map_exceptions(exc_map):
#     208     sock = socket.create_connection(
#     209         address,
#     210         timeout,
#     211         source_address=source_address,
#     212     )
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpcore\_exceptions.py:14, in map_exceptions(map)
#      13     if isinstance(exc, from_exc):
# ---> 14         raise to_exc(exc) from exc
#      15 raise
#
# ConnectError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# ConnectError                              Traceback (most recent call last)
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\openai\_base_client.py:982, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#     981 try:
# --> 982     response = self._client.send(
#     983         request,
#     984         stream=stream or self._should_stream_response_body(request=request),
#     985         **kwargs,
#     986     )
#     987 except httpx.TimeoutException as err:
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpx\_client.py:914, in Client.send(self, request, stream, auth, follow_redirects)
#     912 auth = self._build_request_auth(request, auth)
# --> 914 response = self._send_handling_auth(
#     915     request,
#     916     auth=auth,
#     917     follow_redirects=follow_redirects,
#     918     history=[],
#     919 )
#     920 try:
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpx\_client.py:942, in Client._send_handling_auth(self, request, auth, follow_redirects, history)
#     941 while True:
# --> 942     response = self._send_handling_redirects(
#     943         request,
#     944         follow_redirects=follow_redirects,
#     945         history=history,
#     946     )
#     947     try:
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpx\_client.py:979, in Client._send_handling_redirects(self, request, follow_redirects, history)
#     977     hook(request)
# --> 979 response = self._send_single_request(request)
#     980 try:
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpx\_client.py:1014, in Client._send_single_request(self, request)
#    1013 with request_context(request=request):
# -> 1014     response = transport.handle_request(request)
#    1016 assert isinstance(response.stream, SyncByteStream)
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpx\_transports\default.py:249, in HTTPTransport.handle_request(self, request)
#     237 req = httpcore.Request(
#     238     method=request.method,
#     239     url=httpcore.URL(
#    (...)    247     extensions=request.extensions,
#     248 )
# --> 249 with map_httpcore_exceptions():
#     250     resp = self._pool.handle_request(req)
#
# File C:\Program Files\WindowsApps\PythonSoftwareFoundation.Python.3.12_3.12.2800.0_x64__qbz5n2kfra8p0\Lib\contextlib.py:158, in _GeneratorContextManager.__exit__(self, typ, value, traceback)
#     157 try:
# --> 158     self.gen.throw(value)
#     159 except StopIteration as exc:
#     160     # Suppress StopIteration *unless* it's the same exception that
#     161     # was passed to throw().  This prevents a StopIteration
#     162     # raised inside the "with" statement from being suppressed.
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\httpx\_transports\default.py:118, in map_httpcore_exceptions()
#     117 message = str(exc)
# --> 118 raise mapped_exc(message) from exc
#
# ConnectError: [WinError 10061] No connection could be made because the target machine actively refused it
#
# The above exception was the direct cause of the following exception:
#
# APIConnectionError                        Traceback (most recent call last)
# Cell In[10], line 4
#       1 ollama = OpenAI(base_url='http://localhost:11434/v1', api_key='ollama')
#       2 model_name = "llama3.2"
# ----> 4 response = ollama.chat.completions.create(model=model_name, messages=messages)
#       5 answer = response.choices[0].message.content
#       7 display(Markdown(answer))
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\openai\_utils\_utils.py:286, in required_args.<locals>.inner.<locals>.wrapper(*args, **kwargs)
#     284             msg = f"Missing required argument: {quote(missing[0])}"
#     285     raise TypeError(msg)
# --> 286 return func(*args, **kwargs)
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\openai\resources\chat\completions\completions.py:1147, in Completions.create(self, messages, model, audio, frequency_penalty, function_call, functions, logit_bias, logprobs, max_completion_tokens, max_tokens, metadata, modalities, n, parallel_tool_calls, prediction, presence_penalty, prompt_cache_key, reasoning_effort, response_format, safety_identifier, seed, service_tier, stop, store, stream, stream_options, temperature, tool_choice, tools, top_logprobs, top_p, user, verbosity, web_search_options, extra_headers, extra_query, extra_body, timeout)
#    1101 @required_args(["messages", "model"], ["messages", "model", "stream"])
#    1102 def create(
#    1103     self,
#    (...)   1144     timeout: float | httpx.Timeout | None | NotGiven = not_given,
#    1145 ) -> ChatCompletion | Stream[ChatCompletionChunk]:
#    1146     validate_response_format(response_format)
# -> 1147     return self._post(
#    1148         "/chat/completions",
#    1149         body=maybe_transform(
#    1150             {
#    1151                 "messages": messages,
#    1152                 "model": model,
#    1153                 "audio": audio,
#    1154                 "frequency_penalty": frequency_penalty,
#    1155                 "function_call": function_call,
#    1156                 "functions": functions,
#    1157                 "logit_bias": logit_bias,
#    1158                 "logprobs": logprobs,
#    1159                 "max_completion_tokens": max_completion_tokens,
#    1160                 "max_tokens": max_tokens,
#    1161                 "metadata": metadata,
#    1162                 "modalities": modalities,
#    1163                 "n": n,
#    1164                 "parallel_tool_calls": parallel_tool_calls,
#    1165                 "prediction": prediction,
#    1166                 "presence_penalty": presence_penalty,
#    1167                 "prompt_cache_key": prompt_cache_key,
#    1168                 "reasoning_effort": reasoning_effort,
#    1169                 "response_format": response_format,
#    1170                 "safety_identifier": safety_identifier,
#    1171                 "seed": seed,
#    1172                 "service_tier": service_tier,
#    1173                 "stop": stop,
#    1174                 "store": store,
#    1175                 "stream": stream,
#    1176                 "stream_options": stream_options,
#    1177                 "temperature": temperature,
#    1178                 "tool_choice": tool_choice,
#    1179                 "tools": tools,
#    1180                 "top_logprobs": top_logprobs,
#    1181                 "top_p": top_p,
#    1182                 "user": user,
#    1183                 "verbosity": verbosity,
#    1184                 "web_search_options": web_search_options,
#    1185             },
#    1186             completion_create_params.CompletionCreateParamsStreaming
#    1187             if stream
#    1188             else completion_create_params.CompletionCreateParamsNonStreaming,
#    1189         ),
#    1190         options=make_request_options(
#    1191             extra_headers=extra_headers, extra_query=extra_query, extra_body=extra_body, timeout=timeout
#    1192         ),
#    1193         cast_to=ChatCompletion,
#    1194         stream=stream or False,
#    1195         stream_cls=Stream[ChatCompletionChunk],
#    1196     )
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\openai\_base_client.py:1259, in SyncAPIClient.post(self, path, cast_to, body, options, files, stream, stream_cls)
#    1245 def post(
#    1246     self,
#    1247     path: str,
#    (...)   1254     stream_cls: type[_StreamT] | None = None,
#    1255 ) -> ResponseT | _StreamT:
#    1256     opts = FinalRequestOptions.construct(
#    1257         method="post", url=path, json_data=body, files=to_httpx_files(files), **options
#    1258     )
# -> 1259     return cast(ResponseT, self.request(cast_to, opts, stream=stream, stream_cls=stream_cls))
#
# File c:\Users\joseb\Desktop\Enduring Freedom\AI Projects\Agentic Course\agents\.venv\Lib\site-packages\openai\_base_client.py:1014, in SyncAPIClient.request(self, cast_to, options, stream, stream_cls)
#    1011         continue
#    1013     log.debug("Raising connection error")
# -> 1014     raise APIConnectionError(request=request) from err
#    1016 log.debug(
#    1017     'HTTP Response: %s %s "%i %s" %s',
#    1018     request.method,
#    (...)   1022     response.headers,
#    1023 )
#    1024 log.debug("request_id: %s", response.headers.get("x-request-id"))
#
# APIConnectionError: Connection error.

# %%
# So where are we?

print(competitors)
print(answers)

# %%
# It's nice to know how to use "zip"
for competitor, answer in zip(competitors, answers):
    print(f"Competitor: {competitor}\n\n{answer}")

# %%
# Let's bring this together - note the use of "enumerate"

together = ""
for index, answer in enumerate(answers):
    together += f"# Response from competitor {index+1}\n\n"
    together += answer + "\n\n"

# %%
print(together)

# %%
judge = f"""You are judging a competition between {len(competitors)} competitors.
Each model has been given this question:

{question}

Your job is to evaluate each response for clarity and strength of argument, and rank them in order of best to worst.
Respond with JSON, and only JSON, with the following format:
{{"results": ["best competitor number", "second best competitor number", "third best competitor number", ...]}}

Here are the responses from each competitor:

{together}

Now respond with the JSON with the ranked order of the competitors, nothing else. Do not include markdown formatting or code blocks."""

# %%
print(judge)

# %%
judge_messages = [{"role": "user", "content": judge}]

# %%
# Judgement time!

openai = OpenAI()
response = openai.chat.completions.create(
    model="gpt-5-mini",
    messages=judge_messages,
)
results = response.choices[0].message.content
print(results)

# %%
# OK let's turn this into results!

results_dict = json.loads(results)
ranks = results_dict["results"]
for index, result in enumerate(ranks):
    competitor = competitors[int(result)-1]
    print(f"Rank {index+1}: {competitor}")

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/exercise.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#ff7800;">Exercise</h2>
#             <span style="color:#ff7800;">Which pattern(s) did this use? Try updating this to add another Agentic design pattern.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left; width:100%">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/business.png" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#00bfff;">Commercial implications</h2>
#             <span style="color:#00bfff;">These kinds of patterns - to send a task to multiple models, and evaluate results,
#             are common where you need to improve the quality of your LLM response. This approach can be universally applied
#             to business projects where accuracy is critical.
#             </span>
#         </td>
#     </tr>
# </table>
